# %% [markdown]
# # Data Analysis of VESNA Measurements
# In this Notebook, you can analyse the sample results found in `sample_data/results/` or your own VESNA measurements.
#
# For this, follow the instructions below.

# %%
from functions import plot_measurements

## specify the input folder containing VESNA measurements
input_paths = [
    '../sample_data/results/'
]

## specify labels
labels = ['sample data']


plot_measurements(
    input_paths=input_paths,
    labels=labels,
    layout='horizontal',
    test = False,
    ## if you want to save the figure automatically, specify a file path here:
    # save='sample_plot.png' 
)
